# %% [markdown]
# ## Step 1: clone the repository
#
# Run this in a Colab code cell:
#
# ```python
# !git clone https://github.com/muneebhanif/assignment.git
# %cd /content/assignment/notebooks
# ```

# %% [markdown]
# ## Step 2: upload the dataset
#
# Because the GitHub repository now contains only notebooks, you must upload the CSV files separately.
#
# The easiest option is direct upload into Colab.

# %%
from google.colab import files
uploaded = files.upload()
print('Uploaded files:', list(uploaded.keys()))

# %% [markdown]
# ### Files to upload
# Upload these CSV files:
# - `customers.csv`
# - `drivers.csv`
# - `vehicles.csv`
# - `hubs.csv`
# - `orders.csv`
# - `deliveries.csv`
# - `incidents.csv`
# - `complaints.csv`
# - `app_events.csv`
# - `data_dictionary.csv`

# %%
import os

print('Files now available in /content:')
for name in sorted(os.listdir('/content')):
    print(name)

# %% [markdown]
# ## Step 3: run the notebooks in the correct order
#
# After the CSV files are uploaded, run the notebooks in this order:
#
# 1. `01_python_cleaning.ipynb`
# 2. `02_sql_in_r.ipynb`
# 3. `03_r_analytics.ipynb`
# 4. `04_mongodb_atlas.ipynb`

# %% [markdown]
# ## Step 4: what each notebook needs
#
# - Notebook 1 needs the raw CSV files in `/content`
# - Notebook 2 needs the raw CSV files in `/content`
# - Notebook 3 needs `order_delivery_view.csv`, which you create by running Notebook 1 first
# - Notebook 4 needs the raw CSV files in `/content`

# %% [markdown]
# ## Very simple workflow
#
# 1. Clone the repo
# 2. Upload the CSV files
# 3. Open Notebook 1 and run everything
# 4. Download or keep `order_delivery_view.csv` in `/content`
# 5. Open Notebook 2 and Notebook 3
# 6. Finish with Notebook 4

# %% [markdown]
# ## Important note
#
# If the runtime resets, the uploaded CSV files will disappear. Then upload them again or use Google Drive instead.
