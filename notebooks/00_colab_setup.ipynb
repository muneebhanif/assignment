# %% [markdown]
# # NorthStar - Colab setup guide
#
# Use this notebook first after cloning the GitHub repository in Google Colab.
#
# Now the GitHub repository contains both:
# - the notebooks
# - the dataset CSV files
#
# That means after cloning, you do not need to upload the dataset separately.

# %% [markdown]
# ## Step 1: clone the repository
#
# Run this in a Colab code cell:
#
# ```python
# !git clone https://github.com/muneebhanif/assignment.git
# %cd /content/assignment/notebooks
# ```
#
# After this, the notebooks will be inside `/content/assignment/notebooks` and the dataset files will be in `/content/assignment`.

# %%
import os

print('Notebook folder: /content/assignment/notebooks')
print('Dataset folder: /content/assignment')
print('\nFiles in the repository root:')
for name in sorted(os.listdir('/content/assignment')):
    print(name)

# %% [markdown]
# ## Step 2: no manual upload is needed
#
# Because the GitHub repository now contains the CSV files, you do not need to upload the dataset after cloning.
#
# Just make sure these files are visible in `/content/assignment`:
# - `customers.csv`
# - `drivers.csv`
# - `vehicles.csv`
# - `hubs.csv`
# - `orders.csv`
# - `deliveries.csv`
# - `incidents.csv`
# - `complaints.csv`
# - `app_events.csv`
# - `data_dictionary.csv`

# %%
import os

required_files = [
    'customers.csv',
    'drivers.csv',
    'vehicles.csv',
    'hubs.csv',
    'orders.csv',
    'deliveries.csv',
    'incidents.csv',
    'complaints.csv',
    'app_events.csv',
    'data_dictionary.csv',
]

missing_files = [name for name in required_files if not os.path.exists(f'/content/assignment/{name}')]

if missing_files:
    print('Missing files:', missing_files)
else:
    print('All dataset files are available in /content/assignment')

# %% [markdown]
# ## Step 3: run the notebooks in the correct order
#
# After cloning, run the notebooks in this order:
#
# 1. `01_python_cleaning.ipynb`
# 2. `02_sql_in_r.ipynb`
# 3. `03_r_analytics.ipynb`
# 4. `04_mongodb_atlas.ipynb`
#
# Notebook 1 creates the cleaned file used later by Notebook 3.

# %% [markdown]
# ## Step 4: what each notebook needs
#
# - Notebook 1 reads the raw CSV files from `/content/assignment`
# - Notebook 2 reads the raw CSV files from `/content/assignment`
# - Notebook 3 reads `order_delivery_view.csv` from `/content/assignment/outputs_python`
# - Notebook 4 reads the raw CSV files from `/content/assignment`

# %% [markdown]
# ## Very simple workflow
#
# 1. Clone the repo
# 2. Open Notebook 1
# 3. Run it from top to bottom
# 4. Notebook 1 will create `order_delivery_view.csv`
# 5. Open Notebook 2 and Notebook 3
# 6. Finish with Notebook 4
#
# So after cloning, your next real step is just to run Notebook 1.

# %% [markdown]
# ## Important note
#
# If Colab runtime resets, just clone the repository again. The notebooks and dataset will come back together from GitHub.
